# %%
from pathlib import Path
#On Boarding
import pandas as pd  # pip install pandas openpyxl
import win32com.client as win32  # pip install pywin32

# Locate examples files & create output directory
EXCEL_FILE_PATH = Path.cwd() / "Financial_Data.xlsx"
ATTACHMENT_DIR = Path.cwd() / "Attachments"

ATTACHMENT_DIR.mkdir(exist_ok=True)

# Load financial data into dataframe
#data = pd.read_excel(EXCEL_FILE_PATH, sheet_name="Data")

# Get unique values from any particular column
#column_name = "Country"
#unique_values = data[column_name].unique()

# Load email distribution list into dataframe
email_list = pd.read_excel(EXCEL_FILE_PATH, sheet_name="Email_List")

# Iterate over email distribution list & send emails via Outlook App
outlook = win32.Dispatch("outlook.application")
for index, row in email_list.iterrows():
    mail = outlook.CreateItem(0)
    mail.To = row["Email"]
    mail.CC = row["CC"]
    mail.Subject = f"TSB Onboarding Procedure - {row['Name']} - {row['EMP']} "
    mail.HTMLBody =f"""<b>Hi {row['Name']}</b>,<br><br>     
<b>Please note , we have regulatory obligations to complete below mandatory actions for all resources in TSB project.</b><br><br>
<b>Kindly go through the below email and action accordingly.</b><br><br>

......................................................................................................................................................................................................................................................................................<br>

Dear User,<br>

 

Welcome!<br><br>  


We are delighted to have you among us. On behalf of all team members, I would like to extend our warmest welcome and good wishes!<br>


This e-mail is important as it explains the Onboarding process to this project. Therefore, read this e-mail carefully.<br><br>

 

Below are all the on-boarding steps, the necessary TRAINING and SYSTEM REQUIREMENT CHECKS based on the special requirements generated by the contract between IBM and TSB Bank. Please take into consideration, that the below steps need full completion as soon as possible.<br><br>

 

Please take the time and accomplish all the mandatory on-boarding activities listed below.<br><br>

 

Should there be any questions or assistance needed, please let me know.<br><br>

 

For ILC code, please connect with syedsi12@in.ibm.com with your DOJ and squad details.<br>

Save a mugshot with TSB logo:<br>

<a href='https://ibm.ent.box.com/folder/125692855146?s=exhl9ee9xm9no7xwcix5sg7cnb6a4dxr'>https://ibm.ent.box.com/folder/125692855146?s=exhl9ee9xm9no7xwcix5sg7cnb6a4dxr</a><br><br><br>

 

ACTIONS NEEDED:<br>

 

READ & ACKNOWLEDGE - Please review all materials bellow and complete the necessary training & actions:<br>

 

COMPLETE TRAINING & SEND CONFIRMATION<br><br>

 

1. Confirm the completion of the Business conduct Guideline E-learning as soon as possible. The training can be found at this link:<a href=' https://yourlearning.ibm.com/activity/WWBCG-BCG20220215'> https://yourlearning.ibm.com/activity/WWBCG-BCG20220215</a> <br><br><br>               

<b>Attach a screenshot of it.</b><br><br>

2. Confirm that you have read the DS&P_Contract_Specific_Training_TSB.pptx in the latest attachement below, and the Onboarding pack V5, Access Role Matrix, FAQ found here: <a href='https://ibm.ent.box.com/folder/108044455914'>https://ibm.ent.box.com/folder/108044455914</a> <br>

 

Attach the training here<br><br><br>

 

3.  Please go through the following courses, if not completed before:<br>

GDPR Essential for GBS (3 hours) from this link:<a href='https://bundles.yourlearning.ibm.com/ibm/gbs-biso/#YZRJWKWRRJYW13VE'> https://bundles.yourlearning.ibm.com/ibm/gbs-biso/#YZRJWKWRRJYW13VE</a> <br><br><br>

<b>Attach a screenshot of it.</b><br><br>
 

<b>For Developers only:</b><br><br>

Open Source - OSS / IBM OSPG training : <a href='https://w3.ibm.com/developer/docs/open-source/training/'>https://w3.ibm.com/developer/docs/open-source/training/</a>  <br>

 <b>Attach a screenshot of it.</b><br><br>

Security and Privacy for Developers 101: <a href='https://yourlearning.ibm.com/activity/PLAN-7D6F2B8A5C8F'>https://yourlearning.ibm.com/activity/PLAN-7D6F2B8A5C8F </a> <br>

 <b>Attach a screenshot of it.</b><br><br>

4. <b>Confirm the statement below</b> <br><br>

 

     <b>"Note that working on the contract may give you access to Personal Information, Sensitive Personal Information or Business Sensitive Information.</b><br>

     <b>By agreeing, you confirm to have been made aware of this, have done the Project specific training and will treat this access as per Business Conduct Guideline.</b>”<br><br>

 

5. Check Beekeeper tool compliance at the following link: <a href='https://beekeeper.us1a.cirrus.ibm.com'>https://beekeeper.us1a.cirrus.ibm.com </a> , and <b>attach a screenshot of it.</b><br><br>

 

6. Kindly reply as "Agree" to below mentioned mandatory DS&P requirements. <br>

 

    Kindly go through the content mentioned in below link:<br><br>

 

Every employee is required to read and certify they understand, and agree to adhere to IBM Guidelines prior to any participation in mobile/macOS/other deliverables related projects on behalf of IBM or a Client, including; see following link:<br>

<a href='https://w3.ibm.com/developer/appservices/ibm-guidelines/certify'>https://w3.ibm.com/developer/appservices/ibm-guidelines/certify</a> <br><br><br>

 

7. Kindly go through the attached word document: <br>

 

The Home Worker Security Checklist has been completed.<br><br>

 

 

Thank you,<br>
Aditta Kumar  | PMO support - TSB |adittk33@in.ibm.com  |+91 9874243246 <br><br>

"""    
   # mail.HTMLBody = f"""
   #                <b>Hi {row['Name']}</b>,<br><br>
   #                 Please find attached the report for {row['Country']}.<br><br>
   #                 Best Regards,<br>
   #                 Sven
   #                 """
    attachment_path1 = str(ATTACHMENT_DIR / "DS&P_Contract_Specific_Training_TSB  .pptx")
    attachment_path2 = str(ATTACHMENT_DIR / "Home_Worker_Security_Checklist_template  .doc")
    attachment_path3 = str(ATTACHMENT_DIR / "Onboarding Pack 2022 for TSB.pptx")
    
    mail.Attachments.Add(Source=attachment_path1)
    mail.Attachments.Add(Source=attachment_path2)
    mail.Attachments.Add(Source=attachment_path3)
    
    mail.display()
   # mail.Send()

#Uncomment to send email

# %%
from pathlib import Path
#off Boarding
from docxtpl import DocxTemplate
import pandas as pd  # pip install pandas openpyxl
import win32com.client as win32  # pip install pywin32

# Locate examples files & create output directory
EXCEL_FILE_PATH = Path.cwd() / "Financial_Data.xlsx"
ATTACHMENT_DIR = Path.cwd() / "Attachments"

ATTACHMENT_DIR.mkdir(exist_ok=True)

# Load financial data into dataframe
#data = pd.read_excel(EXCEL_FILE_PATH, sheet_name="Data")


# Load email distribution list into dataframe
email_list = pd.read_excel(EXCEL_FILE_PATH, sheet_name="Email_List")
for index, row in email_list.iterrows():
    
    doc=DocxTemplate(Path.cwd()/ "Off-Boarding_Data_Removal_Certificate TSB.docx")

    context={
    'EMP':f"{row['EMP']}",
    'NAME':f"{row['Name']}",
    'LWD':f"{row['Last Working Day']}"
    }

    doc.render(context)
    doc.save(f"Off-Boarding_Data_Removal_Certificate TSB_{row['Last Working Day']}_{row['Name']}.docx")
    

# Iterate over email distribution list & send emails via Outlook App
outlook = win32.Dispatch("outlook.application")
for index, row in email_list.iterrows():
    mail = outlook.CreateItem(0)
    mail.To = row["Email"]
    mail.CC = row["CC"]
    mail.Subject = f"TSB Offboarding Procedure - {row['Name']} - {row['EMP']} "
    mail.HTMLBody =f"""<b>Hi {row['Name']}</b>,<br><br>  
 
As I understood, you are getting Offboarded from TSB project, therefore as a completion of your assignment and in regards to the account Off-boarding procedure and IBM Data Security & Privacy policy, I kindly ask you: <br><br>
 
 <b>Please Complete Mandatory Action:</b><br>
 <b>  1 </b>To fill in the offboarding data Removal form attached provide all details that are marked in Red colour,<br>
  
Kindly provide your acceptance emailing your PM on the below point. Reply as 'I Agree'.<br>
 <b>"I have ensured that all the supporting applications and data pertaining to TSB has been removed from the current Laptop and IBM Assets that I hold".</b><br>
    
 <b>  2 </b>To electronically sign offboarding data Removal form the document below,<br>
 <b>  3 </b>To have it approved by your Manager by email, using a simple statement: <b> "I approve"</b><br>
 <b>  4 </b>return the e-mail with your manager's approval to me or keep me in cc.<br><br>
 
    In addition, please confirm the following:<br>
 
    -Confirm that GBS off-boarding video, which has further guidance on protecting customer information, has been viewed: https://ibm.ent.box.com/s/0o5rqx9466e89gc8ns44jw6bcj9f54hu <br>
    
 <a href='https://ibm.ent.box.com/s/0o5rqx9466e89gc8ns44jw6bcj9f54hu'>https://ibm.ent.box.com/s/0o5rqx9466e89gc8ns44jw6bcj9f54hu</a><br>
    -Client badges were returned on the last day of the assignment.<br><br>

Thank you in advance for your efforts and for your collaboration<br>
 

Thank you,<br>
Aditta Kumar  | PMO support - TSB |adittk33@in.ibm.com  |+91 9874243246 <br><br>

"""    
   # mail.HTMLBody = f"""
   #                <b>Hi {row['Name']}</b>,<br><br>
   #                 Please find attached the report for {row['Country']}.<br><br>
   #                 Best Regards,<br>
   #                 Sven
   #                 """
    attachment_path = str(Path.cwd()/ f"Off-Boarding_Data_Removal_Certificate TSB_{row['Last Working Day']}_{row['Name']}.docx")
    
    mail.Attachments.Add(Source=attachment_path)
  

    mail.display()
#    mail.Send()

#Uncomment to send email
